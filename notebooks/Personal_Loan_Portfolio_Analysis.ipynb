# %% [markdown]
# # Personal Loan Portfolio Analysis
#
# Python Data Science project using **pandas, numpy, matplotlib and seaborn**.
#
# This notebook walks through the same pipeline implemented in `src/loan_analysis.py`
# and `src/eda.py`: data loading, quality checks, cleaning, descriptive statistics,
# segment analysis and business insights.

# %%
import sys, os
sys.path.append(os.path.abspath(os.path.join('..', 'src')))

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import eda
import loan_analysis

sns.set_theme(style='whitegrid')
# %matplotlib inline

# %% [markdown]
# ## 1. Load the dataset

# %%
df_raw = eda.load_data()
eda.dataset_overview(df_raw)

# %% [markdown]
# ## 2. Data quality: missing values and duplicates

# %%
eda.missing_value_report(df_raw)
eda.duplicate_report(df_raw)

# %% [markdown]
# ## 3. Clean the data

# %%
df = loan_analysis.clean_data(df_raw)
df.head()

# %% [markdown]
# ## 4. Descriptive statistics

# %%
eda.descriptive_statistics(df.drop(columns=['ID', 'ZIPCode'], errors='ignore'))

# %% [markdown]
# ## 5. Customer attribute analysis

# %%
loan_analysis.analyze_age(df)
loan_analysis.analyze_income(df)
loan_analysis.analyze_education(df)
loan_analysis.analyze_family(df)
loan_analysis.analyze_mortgage(df);

# %% [markdown]
# ## 6. Loan acceptance and relationships

# %%
loan_analysis.analyze_loan_acceptance(df)
corr = loan_analysis.analyze_relationships(df)
corr

# %% [markdown]
# ## 7. Visualizations

# %%
eda.generate_all_visualizations(df);

# %% [markdown]
# ## 8. Business insights

# %%
insights = loan_analysis.business_insights(df, corr)
